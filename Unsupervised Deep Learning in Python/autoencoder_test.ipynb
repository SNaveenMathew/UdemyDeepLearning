# %%
from autoencoder_tf_copy import test_pretraining_dnn, test_single_autoencoder

# %%
test_pretraining_dnn()
# Out:
# C:\Users\Naveen\Desktop\Coding\UdemyDeepLearning\Unsupervised Deep Learning in Python\util.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   train = read_csv("train.csv").as_matrix().astype(np.float32)
# training autoencoder: 0
# epoch: 0
# j / n_batches: 0 / 410 cost: 8.533213
# j / n_batches: 10 / 410 cost: 0.31379244
# j / n_batches: 20 / 410 cost: 0.24268405
# j / n_batches: 30 / 410 cost: 0.20207006
# j / n_batches: 40 / 410 cost: 0.19469388
# j / n_batches: 50 / 410 cost: 0.1861893
# j / n_batches: 60 / 410 cost: 0.17396808
# j / n_batches: 70 / 410 cost: 0.16525988
# j / n_batches: 80 / 410 cost: 0.16767468
# j / n_batches: 90 / 410 cost: 0.15713364
# j / n_batches: 100 / 410 cost: 0.15902716
# j / n_batches: 110 / 410 cost: 0.1534057
# j / n_batches: 120 / 410 cost: 0.1472948
# j / n_batches: 130 / 410 cost: 0.14884701
# j / n_batches: 140 / 410 cost: 0.14819303
# j / n_batches: 150 / 410 cost: 0.13885607
# ...

# %%
test_single_autoencoder()
# Out:
# training autoencoder: 0
# epoch: 0
# j / n_batches: 0 / 410 cost: 4.681607
# j / n_batches: 10 / 410 cost: 0.30441368
# j / n_batches: 20 / 410 cost: 0.24620774
# j / n_batches: 30 / 410 cost: 0.21956892
# j / n_batches: 40 / 410 cost: 0.18890738
# j / n_batches: 50 / 410 cost: 0.18646115
# j / n_batches: 60 / 410 cost: 0.17435198
# j / n_batches: 70 / 410 cost: 0.17577742
# j / n_batches: 80 / 410 cost: 0.17762056
# j / n_batches: 90 / 410 cost: 0.17010225
# j / n_batches: 100 / 410 cost: 0.15703425
# j / n_batches: 110 / 410 cost: 0.15984343
# j / n_batches: 120 / 410 cost: 0.15853558
# j / n_batches: 130 / 410 cost: 0.15513921
# j / n_batches: 140 / 410 cost: 0.14927508
# j / n_batches: 150 / 410 cost: 0.15180679
# j / n_batches: 160 / 410 cost: 0.14811048
# j / n_batches: 170 / 410 cost: 0.14739145
# j / n_batches: 180 / 410 cost: 0.14387296
# j / n_batches: 190 / 410 cost: 0.15743835
# j / n_batches: 200 / 410 cost: 0.1392518
# j / n_batches: 210 / 410 cost: 0.14534378
# ...
